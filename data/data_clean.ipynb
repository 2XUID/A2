# %%
import numpy as np
import pandas as pd

ufo_data = pd.read_csv('complete_clean.csv', low_memory=False)

# %%
ufo_data
# Out:
#                datetime                   city   state country     shape  \
# 0      10/10/1949 20:30             san marcos      TX      US  cylinder
# 1      10/10/1949 21:00           lackland afb      TX      US     light
# 2      10/10/1955 17:00   chester (uk/england)  EUROPE      GB    circle
# 3      10/10/1956 21:00                   edna      TX      US    circle
# 4      10/10/1960 20:00                kaneohe      HI      US     light
# ...                 ...                    ...     ...     ...       ...
# 16541   9/09/2012 20:00           murfreesboro      TN      US    sphere
# 16542    9/09/2013 9:51              san diego      CA      US     light
# 16543   9/09/2013 20:15                clifton      NJ      US     other
# 16544   9/09/2013 21:00  hamstead (hollyridge)      NC      US     light
# 16545   9/09/2013 21:15              nashville      TN      US     light
#
#        duration                                           comments   latitude  \
# ...
